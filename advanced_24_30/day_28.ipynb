# %%
import streamlit as st
from streamlit_shap import st_shap
import shap
from sklearn.model_selection import train_test_split
import xgboost
import numpy as np
import pandas as pd

st.set_page_config(layout="wide")

# shap lib로 데이터셋 로드
@st.experimental_memo
def load_data():
    return shap.datasets.adult()

@st.experimental_memo
def load_model(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)
    d_train = xgboost.DMatrix(X_train, label=y_train)
    d_test = xgboost.DMatrix(X_test, label=y_test)
    params = {
        "eta": 0.01,
        "objective": "binary:logistic",
        "subsample": 0.5,
        "base_score": np.mean(y_train),
        "eval_metric": "logloss",
        "n_jobs": -1,
    }
    model = xgboost.train(params, d_train, 10, evals = [(d_test, "test")], verbose_eval=100, early_stopping_rounds=20)
    return model

# 앱 제목 표시
st.title("`streamlit-shap`로 Streamlit 앱에서 SHAP 플롯 표시하기")


# 앱 설명 제공 정보 박스
with st.expander('앱에 대하여'):
    st.markdown('''[`streamlit-shap`](https://github.com/snehankekre/streamlit-shap)는 [SHAP](https://github.com/slundberg/shap) 플롯을 [Streamlit](https://streamlit.io/)에서 표시하기 위한 래퍼를 제공하는 Streamlit 컴포넌트입니다.
                    이 라이브러리는 저희 내부 직원인 [스네한 케크레](https://github.com/snehankekre)가 개발했으며, [Streamlit 문서화](https://docs.streamlit.io/) 웹사이트도 관리합니다.
                ''')

st.header('입력 데이터')
X, y = load_data()
X_display, y_display = shap.datasets.adult(display=True)

with st.expander('데이터에 대하여'):
    st.write('예시 데이터셋으로 성인 인구 조사 데이터를 사용합니다.')
with st.expander('X'):
    st.dataframe(X)
with st.expander('y'):
    st.dataframe(y)

st.header('SHAP 출력')

# XGBoost 모델 훈련
X, y = load_data()
X_display, y_display = shap.datasets.adult(display=True)

model = load_model(X, y)

# SHAP 값 계산
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

with st.expander('워터폴 플롯'):
    st_shap(shap.plots.waterfall(shap_values[0]), height=300)
with st.expander('비스웜 플롯'):
    st_shap(shap.plots.beeswarm(shap_values), height=300)

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

with st.expander('포스 플롯'):
    st.subheader('첫 번째 데이터 인스턴스')
    st_shap(shap.force_plot(explainer.expected_value, shap_values[0,:], X_display.iloc[0,:]), height=200, width=1000)
    st.subheader('첫 천 번째 데이터 인스턴스')
    st_shap(shap.force_plot(explainer.expected_value, shap_values[:1000,:], X_display.iloc[:1000,:]), height=400, width=1000)
# Out:
# 2025-06-27 16:22:14.867 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 12
#       9 st.set_page_config(layout="wide")
#      11 # shap lib로 데이터셋 로드
# ---> 12 @st.experimental_memo
#      13 def load_data():
#      14     return shap.datasets.adult()
#      16 @st.experimental_memo
#      17 def load_model(X, y):
#
# AttributeError: module 'streamlit' has no attribute 'experimental_memo'

# %%
pip install streamlit_shap
# Out:
# Collecting streamlit_shap
#   Using cached streamlit_shap-1.0.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting shap>=0.4.0 (from streamlit_shap)
#   Downloading shap-0.48.0-cp313-cp313-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from shap>=0.4.0->streamlit_shap) (2.3.1)
# Collecting scipy (from shap>=0.4.0->streamlit_shap)
#   Using cached scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn (from shap>=0.4.0->streamlit_shap)
#   Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: pandas in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from shap>=0.4.0->streamlit_shap) (2.3.0)
# Collecting tqdm>=4.27.0 (from shap>=0.4.0->streamlit_shap)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: packaging>20.9 in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from shap>=0.4.0->streamlit_shap) (25.0)
# Collecting slicer==0.0.8 (from shap>=0.4.0->streamlit_shap)
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap>=0.4.0->streamlit_shap)
#   Downloading numba-0.61.2-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Collecting cloudpickle (from shap>=0.4.0->streamlit_shap)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from shap>=0.4.0->streamlit_shap) (4.14.0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.54->shap>=0.4.0->streamlit_shap)
#   Downloading llvmlite-0.44.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Collecting numpy (from shap>=0.4.0->streamlit_shap)
#   Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: colorama in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from tqdm>=4.27.0->shap>=0.4.0->streamlit_shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from pandas->shap>=0.4.0->streamlit_shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from pandas->shap>=0.4.0->streamlit_shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from pandas->shap>=0.4.0->streamlit_shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap>=0.4.0->streamlit_shap) (1.17.0)
# Collecting joblib>=1.2.0 (from scikit-learn->shap>=0.4.0->streamlit_shap)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->shap>=0.4.0->streamlit_shap)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached streamlit_shap-1.0.2-py3-none-any.whl (4.8 kB)
# Downloading shap-0.48.0-cp313-cp313-win_amd64.whl (545 kB)
#    ---------------------------------------- 0.0/545.1 kB ? eta -:--:--
#    ---------------------------------------- 545.1/545.1 kB 7.7 MB/s eta 0:00:00
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading numba-0.61.2-cp313-cp313-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 30.1 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp313-cp313-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ------- -------------------------------- 6.0/30.3 MB 48.2 MB/s eta 0:00:01
#    -------------- ------------------------- 11.0/30.3 MB 27.7 MB/s eta 0:00:01
#    -------------------- ------------------- 15.2/30.3 MB 24.0 MB/s eta 0:00:01
#    --------------------------------- ------ 25.2/30.3 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------ --- 28.0/30.3 MB 27.0 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 25.9 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------------------- ------------------ 6.8/12.6 MB 35.4 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 19.9 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    --------------- ------------------------ 4.2/10.7 MB 33.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.7 MB 19.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.7 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 14.4 MB/s eta 0:00:00
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/38.4 MB 18.0 MB/s eta 0:00:02
#    ------- -------------------------------- 7.6/38.4 MB 18.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.3/38.4 MB 18.7 MB/s eta 0:00:02
#    ------------- -------------------------- 12.8/38.4 MB 15.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.7/38.4 MB 15.2 MB/s eta 0:00:02
#    ------------------- -------------------- 18.9/38.4 MB 15.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.2/38.4 MB 14.8 MB/s eta 0:00:02
#    ------------------------ --------------- 23.6/38.4 MB 14.1 MB/s eta 0:00:02
#    ------------------------- -------------- 24.1/38.4 MB 13.0 MB/s eta 0:00:02
#    --------------------------- ------------ 26.2/38.4 MB 12.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.0/38.4 MB 12.1 MB/s eta 0:00:01
#    ------------------------------ --------- 29.6/38.4 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 31.2/38.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 34.6/38.4 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 38.4/38.4 MB 11.2 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: tqdm, threadpoolctl, slicer, numpy, llvmlite, joblib, cloudpickle, scipy, numba, scikit-learn, shap, streamlit_shap
#
#    ----------------------------------------  0/12 [tqdm]
#    ----------------------------------------  0/12 [tqdm]
#   Attempting uninstall: numpy
#    ----------------------------------------  0/12 [tqdm]
#     Found existing installation: numpy 2.3.1
#    ----------------------------------------  0/12 [tqdm]
#    ---------- -----------------------------  3/12 [numpy]
#     Uninstalling numpy-2.3.1:
#    ---------- -----------------------------  3/12 [numpy]
#       Successfully uninstalled numpy-2.3.1
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ---------- -----------------------------  3/12 [numpy]
#    ------------- --------------------------  4/12 [llvmlite]
#    ------------- --------------------------  4/12 [llvmlite]
#    ------------- --------------------------  4/12 [llvmlite]
#    ------------- --------------------------  4/12 [llvmlite]
#    ------------- --------------------------  4/12 [llvmlite]
#    ---------------- -----------------------  5/12 [joblib]
#    ---------------- -----------------------  5/12 [joblib]
#    ---------------- -----------------------  5/12 [joblib]
#    ---------------- -----------------------  5/12 [joblib]
#    ---------------- -----------------------  5/12 [joblib]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    ----------------------- ----------------  7/12 [scipy]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    -------------------------- -------------  8/12 [numba]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    ------------------------------ ---------  9/12 [scikit-learn]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    --------------------------------- ------ 10/12 [shap]
#    ---------------------------------------- 12/12 [streamlit_shap]
#
# Successfully installed cloudpickle-3.1.1 joblib-1.5.1 llvmlite-0.44.0 numba-0.61.2 numpy-2.2.6 scikit-learn-1.7.0 scipy-1.16.0 shap-0.48.0 slicer-0.0.8 streamlit_shap-1.0.2 threadpoolctl-3.6.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\jhjgo\miniconda3\envs\newenv\lib\site-packages (from xgboost) (1.16.0)
# Using cached xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.2
# Note: you may need to restart the kernel to use updated packages.
